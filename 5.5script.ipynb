# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("/content/drive/MyDrive/Project1_processed/Chapter5.xlsx","5.5")
df.head(10)
# Out:
#   तालिका 5.5: विधानसभाओं में महिलाओं की राज्यवार भागीदारी  \
# 0  Table 5.5: State-wise participation of women i...
# 1                                             राज्‍य
# 2                                                NaN
# 3                                                NaN
# 4                                                (1)
# 5                                       आंध्र प्रदेश
# 6                                     अरुणाचल प्रदेश
# 7                                                असम
# 8                                              बिहार
# 9                                          छत्तीसगढ़
#
#                                     Unnamed: 1 Unnamed: 2  \
# 0                                          NaN        NaN
# 1          राज्य / विधानसभा के संविधान का वर्ष       अवधि
# 2   Year of Constitution of the State/Assembly       Term
# 3                                          NaN        NaN
# 4                                          (2)        (3)
# ...

# %%
df.dropna(thresh=abs(df.shape[1]*0.5),axis=0, inplace=True)
df.dropna(how="all", axis=1, inplace=True)
df.head(10)
# Out:
#    तालिका 5.5: विधानसभाओं में महिलाओं की राज्यवार भागीदारी  \
# 1                                              राज्‍य
# 2                                                 NaN
# 4                                                 (1)
# 5                                        आंध्र प्रदेश
# 6                                      अरुणाचल प्रदेश
# 7                                                 असम
# 8                                               बिहार
# 9                                           छत्तीसगढ़
# 10                                             दिल्ली
# 11                                               गोवा
#
#                                      Unnamed: 1 Unnamed: 2  \
# 1           राज्य / विधानसभा के संविधान का वर्ष       अवधि
# 2    Year of Constitution of the State/Assembly       Term
# 4                                           (2)        (3)
# 5                                          1955         14
# 6                                          1978          8
# ...

# %%
df.tail(10)
# Out:
#    तालिका 5.5: विधानसभाओं में महिलाओं की राज्यवार भागीदारी Unnamed: 1  \
# 27                                          पुडुचेरी             1963
# 28                                           राजस्थान            1956
# 29                                            सिक्किम            1975
# 30                                           तमिलनाडु            1937
# 31                                          तेलंगाना             2014
# 32                                           त्रिपुरा            1972
# 33                                       उत्तर प्रदेश            1937
# 34                                          उत्तराखंड            2000
# 35                                       पश्चिम बंगाल            1937
# 36                                               कुल                -
#
#    Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 27         13       2021         29          1   3.333333         30
# ...

# %%
df.drop(index=[df.index[0], df.index[2],df.index[34]], inplace=True)
df.head(5)
# Out:
#   तालिका 5.5: विधानसभाओं में महिलाओं की राज्यवार भागीदारी  \
# 2                                                NaN
# 5                                       आंध्र प्रदेश
# 6                                     अरुणाचल प्रदेश
# 7                                                असम
# 8                                              बिहार
#
#                                     Unnamed: 1 Unnamed: 2  \
# 2   Year of Constitution of the State/Assembly       Term
# 5                                         1955         14
# 6                                         1978          8
# 7                                    1937/1951         14
# 8                                    1937/1951         15
#
#                   Unnamed: 3 Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7  \
# 2  Year of Assembly election      पुरुष    महिलाएं  Women* (%)     Total
# 5                       2019        161         14           8        175
# ...

# %%
df.drop(columns=[df.columns[0],df.columns[6]],inplace=True)

# %%
df.columns=df.iloc[0,:].values
df.head(5)
# Out:
#     Year of Constitution of the State/Assembly  Term  \
# 2   Year of Constitution of the State/Assembly  Term
# 5                                         1955    14
# 6                                         1978     8
# 7                                    1937/1951    14
# 8                                    1937/1951    15
#
#    Year of Assembly election  पुरुष  महिलाएं  Total                  NaN
# 2  Year of Assembly election  पुरुष  महिलाएं  Total                  NaN
# 5                       2019    161       14     175     Andhra Pradesh
# 6                       2019     57        3      60  Arunachal Pradesh
# 7                       2021    120        6     126              Assam
# 8                       2020    217       26     243              Bihar

# %%
df.drop(index=df.index[0], inplace=True)

# %%
df.rename(columns={df.columns[0]:"year_of_constitution_of_state_assembly", df.columns[1]:"assembly_term",df.columns[2]:"year_of_state_assembly",df.columns[3]:"Elected Male",df.columns[4]:"Elected Female"}, inplace=True)
df.head(5)
# Out:
#   year_of_constitution_of_state_assembly assembly_term year_of_state_assembly  \
# 5                                   1955            14                   2019
# 6                                   1978             8                   2019
# 7                              1937/1951            14                   2021
# 8                              1937/1951            15                   2020
# 9                              2000/2003             4                   2018
#
#   Elected Male Elected Female Total                  NaN
# 5          161             14    175     Andhra Pradesh
# 6           57              3     60  Arunachal Pradesh
# 7          120              6    126              Assam
# 8          217             26    243              Bihar
# 9           77             13     90       Chhattisgarh

# %%
df = df.applymap(lambda x : x.strip() if isinstance(x,str) else x)
df.head(5)
# Out:
#   year_of_constitution_of_state_assembly  assembly_term  \
# 5                                   1955             14
# 6                                   1978              8
# 7                              1937/1951             14
# 8                              1937/1951             15
# 9                              2000/2003              4
#
#    year_of_state_assembly  Elected Male  Elected Female  Total   \
# 5                    2019           161              14     175
# 6                    2019            57               3      60
# 7                    2021           120               6     126
# 8                    2020           217              26     243
# 9                    2018            77              13      90
#
#                  NaN
# 5     Andhra Pradesh
# 6  Arunachal Pradesh
# 7              Assam
# 8              Bihar
# 9       Chhattisgarh

# %%
melt_df=df.melt(id_vars=[df.columns[0],df.columns[1],df.columns[2],df.columns[6]], var_name="category",value_name="value")
melt_df.head(5)
# Out:
#   year_of_constitution_of_state_assembly  assembly_term  \
# 0                                   1955             14
# 1                                   1978              8
# 2                              1937/1951             14
# 3                              1937/1951             15
# 4                              2000/2003              4
#
#    year_of_state_assembly                NaN      category  value
# 0                    2019     Andhra Pradesh  Elected Male    161
# 1                    2019  Arunachal Pradesh  Elected Male     57
# 2                    2021              Assam  Elected Male    120
# 3                    2020              Bihar  Elected Male    217
# 4                    2018       Chhattisgarh  Elected Male     77

# %%
melt_df.rename(columns={melt_df.columns[3]:"state"}, inplace=True)
melt_df.head(5)
# Out:
#   year_of_constitution_of_state_assembly  assembly_term  \
# 0                                   1955             14
# 1                                   1978              8
# 2                              1937/1951             14
# 3                              1937/1951             15
# 4                              2000/2003              4
#
#    year_of_state_assembly              state      category  value
# 0                    2019     Andhra Pradesh  Elected Male    161
# 1                    2019  Arunachal Pradesh  Elected Male     57
# 2                    2021              Assam  Elected Male    120
# 3                    2020              Bihar  Elected Male    217
# 4                    2018       Chhattisgarh  Elected Male     77

# %%
melt_df=melt_df.assign(units="value in absolute number")
melt_df.head(10)
# Out:
#   year_of_constitution_of_state_assembly  assembly_term  \
# 0                                   1955             14
# 1                                   1978              8
# 2                              1937/1951             14
# 3                              1937/1951             15
# 4                              2000/2003              4
# 5                              1992/1993              5
# 6                              1987/1967              6
# 7                              1960/1962             12
# 8                              1966/1967             12
# 9                              1971/1951             12
#
#    year_of_state_assembly              state      category  value  \
# 0                    2019     Andhra Pradesh  Elected Male    161
# 1                    2019  Arunachal Pradesh  Elected Male     57
# 2                    2021              Assam  Elected Male    120
# 3                    2020              Bihar  Elected Male    217
# ...

# %%
melt_df=melt_df[["year_of_constitution_of_state_assembly","year_of_state_assembly", "assembly_term","state","category","value","units"]]
melt_df.head(5)
# Out:
#   year_of_constitution_of_state_assembly  year_of_state_assembly  \
# 0                                   1955                    2019
# 1                                   1978                    2019
# 2                              1937/1951                    2021
# 3                              1937/1951                    2020
# 4                              2000/2003                    2018
#
#    assembly_term              state      category  value  \
# 0             14     Andhra Pradesh  Elected Male    161
# 1              8  Arunachal Pradesh  Elected Male     57
# 2             14              Assam  Elected Male    120
# 3             15              Bihar  Elected Male    217
# 4              4       Chhattisgarh  Elected Male     77
#
#                       units
# 0  value in absolute number
# 1  value in absolute number
# 2  value in absolute number
# 3  value in absolute number
# 4  value in absolute number

# %%
new_df=pd.read_excel('/content/drive/MyDrive/Project1_processed/data_dictionaries.xlsx')
new_df.head(5)
# Out:
#    #REF!                        state
# 0    NaN                    All India
# 1    NaN  Andaman and Nicobar Islands
# 2    NaN               Andhra Pradesh
# 3    NaN            Arunachal Pradesh
# 4    NaN                        Assam

# %%
ref_df=pd.DataFrame(melt_df["state"].unique())
ref_df.head(5)
# Out:
#                    0
# 0     Andhra Pradesh
# 1  Arunachal Pradesh
# 2              Assam
# 3              Bihar
# 4       Chhattisgarh

# %%
list1=new_df["state"].to_list()
list2=ref_df[ref_df.columns[0]].to_list()

# %%
pip install thefuzz
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from thefuzz import process
# Out:
# /usr/local/lib/python3.10/dist-packages/thefuzz/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
from thefuzz import fuzz

# %%
result={}
for i in list2:
  result[i]=process.extractOne(i,list1,scorer=fuzz.ratio)[0]

# %%
melt_df["state"]=melt_df["state"].map(result)

# %%
melt_df = melt_df.applymap(lambda x : x.strip() if isinstance(x,str) else x)
df.head(5)
# Out:
#   year_of_constitution_of_state_assembly  assembly_term  \
# 5                                   1955             14
# 6                                   1978              8
# 7                              1937/1951             14
# 8                              1937/1951             15
# 9                              2000/2003              4
#
#    year_of_state_assembly  Elected Male  Elected Female  Total   \
# 5                    2019           161              14     175
# 6                    2019            57               3      60
# 7                    2021           120               6     126
# 8                    2020           217              26     243
# 9                    2018            77              13      90
#
#                  NaN
# 5     Andhra Pradesh
# 6  Arunachal Pradesh
# 7              Assam
# 8              Bihar
# 9       Chhattisgarh

# %%
melt_df.to_csv("/content/drive/MyDrive/Project1_processed/Table 5.5/output.csv", index=False)
